# %% [markdown]
# ## Download CSVs from URLs

# %%
import time
import urllib3
import os, zipfile
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# You need to get a list of all the urls to download from gdelt (this is what we used: http://data.gdeltproject.org/gdeltv2/masterfilelist.txt). All information is available here: https://blog.gdeltproject.org/gdelt-2-0-our-global-world-in-realtime/
#
# Each url is then used to actually download said zip file with the GDELT data and make them into csv files.

# %%
# get df with urls and filenames
gdelt_url_df = pd.read_csv("GDELT_GKG/extras/GDELT_2022_urls.csv")
# format date
gdelt_url_df["Date_formatted"] = pd.to_datetime(gdelt_url_df['Date'].astype('str').str.slice(start=0,stop=8), infer_datetime_format=True)

# %% [markdown]
# ### Sample URLs

# %%
# get random subset of rows
#samples = gdelt_url_df.sample(n=10, random_state=42)

# %%
# get month subset
samples = gdelt_url_df.loc[(gdelt_url_df['Date_formatted'] >= '2022-07-01')
                         & (gdelt_url_df['Date_formatted'] <= '2022-12-30')]

# %%
samples.shape
# Out:
# (17566, 3)

# %%
print("This should take {} minutes".format(((samples.shape[0] * 142)/100)/60))
# Out:
# This should take 415.7286666666667 minutes

# %% [markdown]
# ### Download CSV files

# %%
# define paths
save_path = "/home/insert_user/GDELT_GKG/"
os.chdir(save_path) # change directory from working dir to dir with files

# %% [markdown]
# Quick function for executing bash commands, for source see https://www.scrapingbee.com/blog/python-wget/

# %%
import subprocess

def runcmd(cmd, verbose = False, *args, **kwargs):
    """
    Function for running bash commands more easily.
    """
    process = subprocess.Popen(
        cmd,
        stdout = subprocess.PIPE,
        stderr = subprocess.PIPE,
        #text = True,
        shell = True
    )
    std_out, std_err = process.communicate()
    if verbose:
        print(std_out.strip(), std_err)
    pass

# %%
print("Now downloading files...")
#samples = samples.head(10) # take subset for time testing

start = time.time()
for filename, url in tqdm(zip(samples["Date"],samples["URL"])):
    # define item name
    item_name = str(filename) + ".gkg.csv.zip"
    csv_name = "/home/insert_user/GDELT_GKG/gkg_csvs/" + str(filename) + ".gkg.csv"
    # file has already been downloaded, either exists as zip or csv, we skip
    if os.path.exists(item_name) or os.path.exists(csv_name):
        continue
    # download URL with bash cmd function
    runcmd("wget {}".format(url), verbose = False)

end = time.time()
print("This took {} s".format(end-start))
# Out:
# Now downloading files...
# 17566it [22:30, 13.01it/s]
# This took 1350.4307177066803 s

# %% [markdown]
# There's a lot of variance in how long each month takes to download: ex. January 2022 took 1h10mins, but February took over 2h.

# %% [markdown]
# Now we check if we get as many files as we expected: (if not, we can simply rerun the code above)

# %%
total_downloads = len(os.listdir(save_path)) + len(os.listdir("/home/insert_user/GDELT_GKG/gkg_csvs"))
print( "We're missing {} files".format(samples.shape[0] - total_downloads) )
# Out:
# We're missing -15581 files

# %% [markdown]
# One week's worth took 7mins 50s to download with urllib3, and 6mins 11s with !wget.

# %% [markdown]
# ### Unzip downloaded files in directory

# %%
print("Now unzipping and deleting zips...")

start = time.time()

for item in tqdm(os.listdir(save_path)): # loop through items in dir
    if item.endswith(".zip"): # check for ".zip" extension
        file_name = os.path.abspath(item) # get full path of files
        try:
            zip_ref = zipfile.ZipFile(file_name) # create zipfile object
            zip_ref.extractall(save_path + "/gkg_csvs") # extract file to dir
            zip_ref.close() # close file
            os.remove(file_name) # delete zipped file
        except:
            print("Something went wrong with: ")
            print(file_name)
            

end = time.time()
print("This took {} s".format(end-start))
# Out:
# Now unzipping and deleting zips...
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 968.73it/s]
# Something went wrong with:
# /home/ronja/GDELT_GKG/20221021171500.gkg.csv.zip
# This took 0.009716272354125977 s

# %%
# let's check if there are files that were in the samples, but are not downloaded correctly
# just to make sure

start = time.time()
i = 0
for filename, url in tqdm(zip(samples["Date"],samples["URL"])):
    # define item name
    item_name = str(filename) + ".gkg.csv.zip"
    csv_name = "/home/insert_user/GDELT_GKG/gkg_csvs/" + str(filename) + ".gkg.csv"
    
    if not (os.path.exists(item_name) or os.path.exists(csv_name)):
        print("this file doesn't exist either as zip or csv", filename)
        i += 1
        continue

print(i)
# Out:
# 17566it [00:00, 305076.29it/s]
# this file doesn't exist either as zip or csv 20220704113000
# this file doesn't exist either as zip or csv 20220705023000
# this file doesn't exist either as zip or csv 20220706130000
# this file doesn't exist either as zip or csv 20220706131500
# this file doesn't exist either as zip or csv 20220706133000
# this file doesn't exist either as zip or csv 20220706134500
# this file doesn't exist either as zip or csv 20220706140000
# this file doesn't exist either as zip or csv 20220706141500
# this file doesn't exist either as zip or csv 20220706143000
# this file doesn't exist either as zip or csv 20220706144500
# this file doesn't exist either as zip or csv 20220706150000
# this file doesn't exist either as zip or csv 20220706151500
# this file doesn't exist either as zip or csv 20220706153000
# this file doesn't exist either as zip or csv 20220706154500
# this file doesn't exist either as zip or csv 20220706160000
# this file doesn't exist either as zip or csv 20220706161500
# this file doesn't exist either as zip or csv 20220706163000
# this file doesn't exist either as zip or csv 20220706164500
# this file doesn't exist either as zip or csv 20220706170000
# this file doesn't exist either as zip or csv 20220706171500
# this file doesn't exist either as zip or csv 20220706173000
# this file doesn't exist either as zip or csv 20220706174500
# this file doesn't exist either as zip or csv 20220706180000
# this file doesn't exist either as zip or csv 20220706181500
# this file doesn't exist either as zip or csv 20220706183000
# this file doesn't exist either as zip or csv 20220706184500
# this file doesn't exist either as zip or csv 20220706190000
# this file doesn't exist either as zip or csv 20220706191500
# this file doesn't exist either as zip or csv 20220706193000
# this file doesn't exist either as zip or csv 20220706194500
# this file doesn't exist either as zip or csv 20220706200000
# this file doesn't exist either as zip or csv 20220706201500
# this file doesn't exist either as zip or csv 20220706203000
# this file doesn't exist either as zip or csv 20220706204500
# this file doesn't exist either as zip or csv 20220706210000
# this file doesn't exist either as zip or csv 20220706211500
# this file doesn't exist either as zip or csv 20220706213000
# this file doesn't exist either as zip or csv 20220706214500
# this file doesn't exist either as zip or csv 20220706220000
# this file doesn't exist either as zip or csv 20220706221500
# this file doesn't exist either as zip or csv 20220706223000
# this file doesn't exist either as zip or csv 20220706224500
# this file doesn't exist either as zip or csv 20220706230000
# this file doesn't exist either as zip or csv 20220706231500
# this file doesn't exist either as zip or csv 20220706233000
# this file doesn't exist either as zip or csv 20220706234500
# this file doesn't exist either as zip or csv 20220707000000
# this file doesn't exist either as zip or csv 20220707001500
# this file doesn't exist either as zip or csv 20220707003000
# this file doesn't exist either as zip or csv 20220707004500
# this file doesn't exist either as zip or csv 20220707010000
# this file doesn't exist either as zip or csv 20220707011500
# this file doesn't exist either as zip or csv 20220707013000
# this file doesn't exist either as zip or csv 20220707014500
# this file doesn't exist either as zip or csv 20220707020000
# this file doesn't exist either as zip or csv 20220707021500
# this file doesn't exist either as zip or csv 20220707023000
# this file doesn't exist either as zip or csv 20220707024500
# this file doesn't exist either as zip or csv 20220707030000
# this file doesn't exist either as zip or csv 20220707031500
# this file doesn't exist either as zip or csv 20220707033000
# this file doesn't exist either as zip or csv 20220707034500
# this file doesn't exist either as zip or csv 20220707040000
# this file doesn't exist either as zip or csv 20220707041500
# this file doesn't exist either as zip or csv 20220707043000
# this file doesn't exist either as zip or csv 20220707044500
# this file doesn't exist either as zip or csv 20220707050000
# this file doesn't exist either as zip or csv 20220707051500
# this file doesn't exist either as zip or csv 20220707053000
# this file doesn't exist either as zip or csv 20220707054500
# this file doesn't exist either as zip or csv 20220707060000
# this file doesn't exist either as zip or csv 20220707061500
# this file doesn't exist either as zip or csv 20220707063000
# this file doesn't exist either as zip or csv 20220707064500
# this file doesn't exist either as zip or csv 20220707070000
# this file doesn't exist either as zip or csv 20220707071500
# this file doesn't exist either as zip or csv 20220707073000
# this file doesn't exist either as zip or csv 20220707074500
# this file doesn't exist either as zip or csv 20220707080000
# this file doesn't exist either as zip or csv 20220707081500
# this file doesn't exist either as zip or csv 20220707083000
# this file doesn't exist either as zip or csv 20220707084500
# this file doesn't exist either as zip or csv 20220707090000
# this file doesn't exist either as zip or csv 20220707091500
# this file doesn't exist either as zip or csv 20220707093000
# this file doesn't exist either as zip or csv 20220707094500
# this file doesn't exist either as zip or csv 20220707100000
# this file doesn't exist either as zip or csv 20220707101500
# this file doesn't exist either as zip or csv 20220707103000
# this file doesn't exist either as zip or csv 20220707104500
# this file doesn't exist either as zip or csv 20220707110000
# this file doesn't exist either as zip or csv 20220707111500
# this file doesn't exist either as zip or csv 20220707113000
# this file doesn't exist either as zip or csv 20220707114500
# this file doesn't exist either as zip or csv 20220707120000
# this file doesn't exist either as zip or csv 20220707121500
# this file doesn't exist either as zip or csv 20220707123000
# this file doesn't exist either as zip or csv 20220707124500
# this file doesn't exist either as zip or csv 20220707130000
# this file doesn't exist either as zip or csv 20220707131500
# this file doesn't exist either as zip or csv 20220707133000
# this file doesn't exist either as zip or csv 20220707134500
# this file doesn't exist either as zip or csv 20220707140000
# this file doesn't exist either as zip or csv 20220707141500
# this file doesn't exist either as zip or csv 20220707143000
# this file doesn't exist either as zip or csv 20220707144500
# this file doesn't exist either as zip or csv 20220707150000
# this file doesn't exist either as zip or csv 20220707151500
# this file doesn't exist either as zip or csv 20220707153000
# this file doesn't exist either as zip or csv 20220707154500
# this file doesn't exist either as zip or csv 20220707160000
# this file doesn't exist either as zip or csv 20220707161500
# this file doesn't exist either as zip or csv 20220707163000
# this file doesn't exist either as zip or csv 20220707164500
# this file doesn't exist either as zip or csv 20220707170000
# this file doesn't exist either as zip or csv 20220707171500
# this file doesn't exist either as zip or csv 20220707173000
# this file doesn't exist either as zip or csv 20220707174500
# this file doesn't exist either as zip or csv 20220707180000
# this file doesn't exist either as zip or csv 20220707181500
# this file doesn't exist either as zip or csv 20220707183000
# this file doesn't exist either as zip or csv 20220707184500
# this file doesn't exist either as zip or csv 20220707190000
# this file doesn't exist either as zip or csv 20220707191500
# this file doesn't exist either as zip or csv 20220707193000
# this file doesn't exist either as zip or csv 20220707194500
# this file doesn't exist either as zip or csv 20220707200000
# this file doesn't exist either as zip or csv 20220707201500
# this file doesn't exist either as zip or csv 20220707203000
# this file doesn't exist either as zip or csv 20220707204500
# this file doesn't exist either as zip or csv 20220707210000
# this file doesn't exist either as zip or csv 20220707211500
# this file doesn't exist either as zip or csv 20220707213000
# this file doesn't exist either as zip or csv 20220707214500
# this file doesn't exist either as zip or csv 20220707220000
# this file doesn't exist either as zip or csv 20220707221500
# this file doesn't exist either as zip or csv 20220707223000
# this file doesn't exist either as zip or csv 20220707224500
# this file doesn't exist either as zip or csv 20220707230000
# this file doesn't exist either as zip or csv 20220707231500
# this file doesn't exist either as zip or csv 20220707233000
# this file doesn't exist either as zip or csv 20220707234500
# this file doesn't exist either as zip or csv 20220708000000
# this file doesn't exist either as zip or csv 20220708001500
# this file doesn't exist either as zip or csv 20220708003000
# this file doesn't exist either as zip or csv 20220708004500
# this file doesn't exist either as zip or csv 20220708010000
# this file doesn't exist either as zip or csv 20220708011500
# this file doesn't exist either as zip or csv 20220708013000
# this file doesn't exist either as zip or csv 20220708014500
# this file doesn't exist either as zip or csv 20220708020000
# this file doesn't exist either as zip or csv 20220708021500
# this file doesn't exist either as zip or csv 20220708023000
# this file doesn't exist either as zip or csv 20220708024500
# this file doesn't exist either as zip or csv 20220708030000
# this file doesn't exist either as zip or csv 20220708031500
# this file doesn't exist either as zip or csv 20220708033000
# this file doesn't exist either as zip or csv 20220708034500
# this file doesn't exist either as zip or csv 20220708040000
# this file doesn't exist either as zip or csv 20220708041500
# this file doesn't exist either as zip or csv 20220708043000
# this file doesn't exist either as zip or csv 20220708044500
# this file doesn't exist either as zip or csv 20220708050000
# this file doesn't exist either as zip or csv 20220708051500
# this file doesn't exist either as zip or csv 20220708053000
# this file doesn't exist either as zip or csv 20220708054500
# this file doesn't exist either as zip or csv 20220708060000
# this file doesn't exist either as zip or csv 20220708061500
# this file doesn't exist either as zip or csv 20220708063000
# this file doesn't exist either as zip or csv 20220708064500
# this file doesn't exist either as zip or csv 20220708070000
# this file doesn't exist either as zip or csv 20220708071500
# this file doesn't exist either as zip or csv 20220708073000
# this file doesn't exist either as zip or csv 20220708074500
# this file doesn't exist either as zip or csv 20220708080000
# this file doesn't exist either as zip or csv 20220708081500
# this file doesn't exist either as zip or csv 20220708083000
# this file doesn't exist either as zip or csv 20220708084500
# this file doesn't exist either as zip or csv 20220708090000
# this file doesn't exist either as zip or csv 20220708091500
# this file doesn't exist either as zip or csv 20220708093000
# this file doesn't exist either as zip or csv 20220708094500
# this file doesn't exist either as zip or csv 20220708100000
# this file doesn't exist either as zip or csv 20220708101500
# this file doesn't exist either as zip or csv 20220708103000
# this file doesn't exist either as zip or csv 20220708104500
# this file doesn't exist either as zip or csv 20220708110000
# this file doesn't exist either as zip or csv 20220708111500
# this file doesn't exist either as zip or csv 20220708113000
# this file doesn't exist either as zip or csv 20220708114500
# this file doesn't exist either as zip or csv 20220708120000
# this file doesn't exist either as zip or csv 20220708121500
# this file doesn't exist either as zip or csv 20220708123000
# this file doesn't exist either as zip or csv 20220708124500
# this file doesn't exist either as zip or csv 20220708130000
# this file doesn't exist either as zip or csv 20220708131500
# this file doesn't exist either as zip or csv 20220708133000
# this file doesn't exist either as zip or csv 20220708134500
# this file doesn't exist either as zip or csv 20220708140000
# this file doesn't exist either as zip or csv 20220708141500
# this file doesn't exist either as zip or csv 20220708143000
# this file doesn't exist either as zip or csv 20220708144500
# this file doesn't exist either as zip or csv 20220708150000
# this file doesn't exist either as zip or csv 20220708151500
# this file doesn't exist either as zip or csv 20220708153000
# this file doesn't exist either as zip or csv 20220708154500
# this file doesn't exist either as zip or csv 20220708160000
# this file doesn't exist either as zip or csv 20220708161500
# this file doesn't exist either as zip or csv 20220708163000
# this file doesn't exist either as zip or csv 20220708164500
# this file doesn't exist either as zip or csv 20220708170000
# this file doesn't exist either as zip or csv 20220708171500
# this file doesn't exist either as zip or csv 20220708173000
# this file doesn't exist either as zip or csv 20220708174500
# this file doesn't exist either as zip or csv 20220708180000
# this file doesn't exist either as zip or csv 20220708181500
# this file doesn't exist either as zip or csv 20220708183000
# this file doesn't exist either as zip or csv 20220708184500
# this file doesn't exist either as zip or csv 20220708190000
# this file doesn't exist either as zip or csv 20220708191500
# this file doesn't exist either as zip or csv 20220708193000
# this file doesn't exist either as zip or csv 20220708194500
# this file doesn't exist either as zip or csv 20220708200000
# this file doesn't exist either as zip or csv 20220708201500
# this file doesn't exist either as zip or csv 20220708203000
# this file doesn't exist either as zip or csv 20220708204500
# this file doesn't exist either as zip or csv 20220708210000
# this file doesn't exist either as zip or csv 20220708211500
# this file doesn't exist either as zip or csv 20220708213000
# this file doesn't exist either as zip or csv 20220708214500
# this file doesn't exist either as zip or csv 20220708220000
# this file doesn't exist either as zip or csv 20220708221500
# this file doesn't exist either as zip or csv 20220708223000
# this file doesn't exist either as zip or csv 20220708224500
# this file doesn't exist either as zip or csv 20220708230000
# this file doesn't exist either as zip or csv 20220708231500
# this file doesn't exist either as zip or csv 20220708233000
# this file doesn't exist either as zip or csv 20220708234500
# this file doesn't exist either as zip or csv 20220709000000
# this file doesn't exist either as zip or csv 20220709001500
# this file doesn't exist either as zip or csv 20220709003000
# this file doesn't exist either as zip or csv 20220709004500
# this file doesn't exist either as zip or csv 20220709010000
# this file doesn't exist either as zip or csv 20220709011500
# this file doesn't exist either as zip or csv 20220709013000
# this file doesn't exist either as zip or csv 20220709014500
# this file doesn't exist either as zip or csv 20220709020000
# this file doesn't exist either as zip or csv 20220709021500
# this file doesn't exist either as zip or csv 20220709023000
# this file doesn't exist either as zip or csv 20220709024500
# this file doesn't exist either as zip or csv 20220709030000
# this file doesn't exist either as zip or csv 20220709031500
# this file doesn't exist either as zip or csv 20220709033000
# this file doesn't exist either as zip or csv 20220709034500
# this file doesn't exist either as zip or csv 20220709040000
# this file doesn't exist either as zip or csv 20220709041500
# this file doesn't exist either as zip or csv 20220709043000
# this file doesn't exist either as zip or csv 20220709044500
# this file doesn't exist either as zip or csv 20220709050000
# this file doesn't exist either as zip or csv 20220709051500
# this file doesn't exist either as zip or csv 20220709053000
# this file doesn't exist either as zip or csv 20220709054500
# this file doesn't exist either as zip or csv 20220709060000
# this file doesn't exist either as zip or csv 20220709061500
# this file doesn't exist either as zip or csv 20220709063000
# this file doesn't exist either as zip or csv 20220709064500
# this file doesn't exist either as zip or csv 20220709070000
# this file doesn't exist either as zip or csv 20220709071500
# this file doesn't exist either as zip or csv 20220709073000
# this file doesn't exist either as zip or csv 20220709074500
# this file doesn't exist either as zip or csv 20220709080000
# this file doesn't exist either as zip or csv 20220709081500
# this file doesn't exist either as zip or csv 20220709083000
# this file doesn't exist either as zip or csv 20220709084500
# this file doesn't exist either as zip or csv 20220709090000
# this file doesn't exist either as zip or csv 20220709091500
# this file doesn't exist either as zip or csv 20220709093000
# this file doesn't exist either as zip or csv 20220709094500
# this file doesn't exist either as zip or csv 20220709100000
# this file doesn't exist either as zip or csv 20220709101500
# this file doesn't exist either as zip or csv 20220709103000
# this file doesn't exist either as zip or csv 20220709104500
# this file doesn't exist either as zip or csv 20220709110000
# this file doesn't exist either as zip or csv 20220709111500
# this file doesn't exist either as zip or csv 20220709113000
# this file doesn't exist either as zip or csv 20220709114500
# this file doesn't exist either as zip or csv 20220709120000
# this file doesn't exist either as zip or csv 20220709121500
# this file doesn't exist either as zip or csv 20220709123000
# this file doesn't exist either as zip or csv 20220709124500
# this file doesn't exist either as zip or csv 20220709130000
# this file doesn't exist either as zip or csv 20220709131500
# this file doesn't exist either as zip or csv 20220709133000
# this file doesn't exist either as zip or csv 20220709134500
# this file doesn't exist either as zip or csv 20220709140000
# this file doesn't exist either as zip or csv 20220709141500
# this file doesn't exist either as zip or csv 20220709143000
# this file doesn't exist either as zip or csv 20220709144500
# this file doesn't exist either as zip or csv 20220709150000
# this file doesn't exist either as zip or csv 20220709151500
# this file doesn't exist either as zip or csv 20220709153000
# this file doesn't exist either as zip or csv 20220709154500
# this file doesn't exist either as zip or csv 20220709160000
# this file doesn't exist either as zip or csv 20220709161500
# this file doesn't exist either as zip or csv 20220709163000
# this file doesn't exist either as zip or csv 20220709164500
# this file doesn't exist either as zip or csv 20220709170000
# this file doesn't exist either as zip or csv 20220709171500
# this file doesn't exist either as zip or csv 20220709173000
# this file doesn't exist either as zip or csv 20220709174500
# this file doesn't exist either as zip or csv 20220709180000
# this file doesn't exist either as zip or csv 20220709181500
# this file doesn't exist either as zip or csv 20220709183000
# this file doesn't exist either as zip or csv 20220709184500
# this file doesn't exist either as zip or csv 20220709190000
# this file doesn't exist either as zip or csv 20220709191500
# this file doesn't exist either as zip or csv 20220709193000
# this file doesn't exist either as zip or csv 20220709194500
# this file doesn't exist either as zip or csv 20220709200000
# this file doesn't exist either as zip or csv 20220709201500
# this file doesn't exist either as zip or csv 20220709203000
# this file doesn't exist either as zip or csv 20220709204500
# this file doesn't exist either as zip or csv 20220709210000
# this file doesn't exist either as zip or csv 20220709211500
# this file doesn't exist either as zip or csv 20220709213000
# this file doesn't exist either as zip or csv 20220709214500
# this file doesn't exist either as zip or csv 20220709220000
# this file doesn't exist either as zip or csv 20220709221500
# this file doesn't exist either as zip or csv 20220709223000
# this file doesn't exist either as zip or csv 20220709224500
# this file doesn't exist either as zip or csv 20220709230000
# this file doesn't exist either as zip or csv 20220709231500
# this file doesn't exist either as zip or csv 20220709233000
# this file doesn't exist either as zip or csv 20220709234500
# this file doesn't exist either as zip or csv 20220710000000
# this file doesn't exist either as zip or csv 20220710001500
# this file doesn't exist either as zip or csv 20220710003000
# this file doesn't exist either as zip or csv 20220710004500
# this file doesn't exist either as zip or csv 20220710010000
# this file doesn't exist either as zip or csv 20220710011500
# this file doesn't exist either as zip or csv 20220710013000
# this file doesn't exist either as zip or csv 20220710014500
# this file doesn't exist either as zip or csv 20220710020000
# this file doesn't exist either as zip or csv 20220710021500
# this file doesn't exist either as zip or csv 20220710023000
# this file doesn't exist either as zip or csv 20220710024500
# this file doesn't exist either as zip or csv 20220710030000
# this file doesn't exist either as zip or csv 20220710031500
# this file doesn't exist either as zip or csv 20220710033000
# this file doesn't exist either as zip or csv 20220710034500
# this file doesn't exist either as zip or csv 20220710040000
# this file doesn't exist either as zip or csv 20220710041500
# this file doesn't exist either as zip or csv 20220710043000
# this file doesn't exist either as zip or csv 20220710044500
# this file doesn't exist either as zip or csv 20220710050000
# this file doesn't exist either as zip or csv 20220710051500
# this file doesn't exist either as zip or csv 20220710053000
# this file doesn't exist either as zip or csv 20220710054500
# this file doesn't exist either as zip or csv 20220710060000
# this file doesn't exist either as zip or csv 20220710061500
# this file doesn't exist either as zip or csv 20220710063000
# this file doesn't exist either as zip or csv 20220710064500
# this file doesn't exist either as zip or csv 20220710070000
# this file doesn't exist either as zip or csv 20220710071500
# this file doesn't exist either as zip or csv 20220710073000
# this file doesn't exist either as zip or csv 20220710074500
# this file doesn't exist either as zip or csv 20220710080000
# this file doesn't exist either as zip or csv 20220710081500
# this file doesn't exist either as zip or csv 20220710083000
# this file doesn't exist either as zip or csv 20220710084500
# this file doesn't exist either as zip or csv 20220710090000
# this file doesn't exist either as zip or csv 20220710091500
# this file doesn't exist either as zip or csv 20220710093000
# this file doesn't exist either as zip or csv 20220710094500
# this file doesn't exist either as zip or csv 20220710100000
# this file doesn't exist either as zip or csv 20220710101500
# this file doesn't exist either as zip or csv 20220710103000
# this file doesn't exist either as zip or csv 20220710104500
# this file doesn't exist either as zip or csv 20220710110000
# this file doesn't exist either as zip or csv 20220710111500
# this file doesn't exist either as zip or csv 20220710113000
# this file doesn't exist either as zip or csv 20220710114500
# this file doesn't exist either as zip or csv 20220710120000
# this file doesn't exist either as zip or csv 20220710121500
# this file doesn't exist either as zip or csv 20220710123000
# this file doesn't exist either as zip or csv 20220710124500
# this file doesn't exist either as zip or csv 20220710130000
# this file doesn't exist either as zip or csv 20220710131500
# this file doesn't exist either as zip or csv 20220710133000
# this file doesn't exist either as zip or csv 20220710134500
# this file doesn't exist either as zip or csv 20220710140000
# this file doesn't exist either as zip or csv 20220710141500
# this file doesn't exist either as zip or csv 20220710143000
# this file doesn't exist either as zip or csv 20220710144500
# this file doesn't exist either as zip or csv 20220710150000
# this file doesn't exist either as zip or csv 20220710151500
# this file doesn't exist either as zip or csv 20220710153000
# this file doesn't exist either as zip or csv 20220710154500
# this file doesn't exist either as zip or csv 20220710160000
# this file doesn't exist either as zip or csv 20220710161500
# this file doesn't exist either as zip or csv 20220710163000
# this file doesn't exist either as zip or csv 20220710164500
# this file doesn't exist either as zip or csv 20220710170000
# this file doesn't exist either as zip or csv 20220710171500
# this file doesn't exist either as zip or csv 20220710173000
# this file doesn't exist either as zip or csv 20220710174500
# this file doesn't exist either as zip or csv 20220710180000
# this file doesn't exist either as zip or csv 20220710181500
# this file doesn't exist either as zip or csv 20220710183000
# this file doesn't exist either as zip or csv 20220710184500
# this file doesn't exist either as zip or csv 20220710190000
# this file doesn't exist either as zip or csv 20220710191500
# this file doesn't exist either as zip or csv 20220710193000
# this file doesn't exist either as zip or csv 20220710194500
# this file doesn't exist either as zip or csv 20220710200000
# this file doesn't exist either as zip or csv 20220710201500
# this file doesn't exist either as zip or csv 20220710203000
# this file doesn't exist either as zip or csv 20220710204500
# this file doesn't exist either as zip or csv 20220710210000
# this file doesn't exist either as zip or csv 20220710211500
# this file doesn't exist either as zip or csv 20220710213000
# this file doesn't exist either as zip or csv 20220710214500
# this file doesn't exist either as zip or csv 20220710220000
# this file doesn't exist either as zip or csv 20220710221500
# this file doesn't exist either as zip or csv 20220710223000
# this file doesn't exist either as zip or csv 20220710224500
# this file doesn't exist either as zip or csv 20220710230000
# this file doesn't exist either as zip or csv 20220710231500
# this file doesn't exist either as zip or csv 20220710233000
# this file doesn't exist either as zip or csv 20220710234500
# this file doesn't exist either as zip or csv 20220711000000
# this file doesn't exist either as zip or csv 20220711001500
# this file doesn't exist either as zip or csv 20220711003000
# this file doesn't exist either as zip or csv 20220711004500
# this file doesn't exist either as zip or csv 20220711010000
# this file doesn't exist either as zip or csv 20220711011500
# this file doesn't exist either as zip or csv 20220711013000
# this file doesn't exist either as zip or csv 20220711014500
# this file doesn't exist either as zip or csv 20220711020000
# this file doesn't exist either as zip or csv 20220711021500
# this file doesn't exist either as zip or csv 20220711023000
# this file doesn't exist either as zip or csv 20220711024500
# this file doesn't exist either as zip or csv 20220711030000
# this file doesn't exist either as zip or csv 20220711031500
# this file doesn't exist either as zip or csv 20220711033000
# this file doesn't exist either as zip or csv 20220711034500
# this file doesn't exist either as zip or csv 20220711040000
# this file doesn't exist either as zip or csv 20220711041500
# this file doesn't exist either as zip or csv 20220711043000
# this file doesn't exist either as zip or csv 20220711044500
# this file doesn't exist either as zip or csv 20220711050000
# this file doesn't exist either as zip or csv 20220711051500
# this file doesn't exist either as zip or csv 20220711053000
# this file doesn't exist either as zip or csv 20220711054500
# this file doesn't exist either as zip or csv 20220711060000
# this file doesn't exist either as zip or csv 20220711061500
# this file doesn't exist either as zip or csv 20220711063000
# this file doesn't exist either as zip or csv 20220711064500
# this file doesn't exist either as zip or csv 20220711070000
# this file doesn't exist either as zip or csv 20220711071500
# this file doesn't exist either as zip or csv 20220711073000
# this file doesn't exist either as zip or csv 20220711074500
# this file doesn't exist either as zip or csv 20220711080000
# this file doesn't exist either as zip or csv 20220711081500
# this file doesn't exist either as zip or csv 20220711083000
# this file doesn't exist either as zip or csv 20220711084500
# this file doesn't exist either as zip or csv 20220711090000
# this file doesn't exist either as zip or csv 20220711091500
# this file doesn't exist either as zip or csv 20220711093000
# this file doesn't exist either as zip or csv 20220711094500
# this file doesn't exist either as zip or csv 20220711100000
# this file doesn't exist either as zip or csv 20220711101500
# this file doesn't exist either as zip or csv 20220711103000
# this file doesn't exist either as zip or csv 20220711104500
# this file doesn't exist either as zip or csv 20220711110000
# this file doesn't exist either as zip or csv 20220711111500
# this file doesn't exist either as zip or csv 20220711113000
# this file doesn't exist either as zip or csv 20220711114500
# this file doesn't exist either as zip or csv 20220711120000
# this file doesn't exist either as zip or csv 20220711121500
# this file doesn't exist either as zip or csv 20220711123000
# this file doesn't exist either as zip or csv 20220711124500
# this file doesn't exist either as zip or csv 20220711130000
# this file doesn't exist either as zip or csv 20220711131500
# this file doesn't exist either as zip or csv 20220711133000
# this file doesn't exist either as zip or csv 20220711134500
# this file doesn't exist either as zip or csv 20220711140000
# this file doesn't exist either as zip or csv 20220711141500
# this file doesn't exist either as zip or csv 20220711143000
# this file doesn't exist either as zip or csv 20220711144500
# this file doesn't exist either as zip or csv 20220711150000
# this file doesn't exist either as zip or csv 20220711151500
# this file doesn't exist either as zip or csv 20220711153000
# this file doesn't exist either as zip or csv 20220711154500
# this file doesn't exist either as zip or csv 20220711160000
# this file doesn't exist either as zip or csv 20220711161500
# this file doesn't exist either as zip or csv 20220711163000
# this file doesn't exist either as zip or csv 20220711164500
# this file doesn't exist either as zip or csv 20220711170000
# this file doesn't exist either as zip or csv 20220711171500
# this file doesn't exist either as zip or csv 20220711173000
# this file doesn't exist either as zip or csv 20220711174500
# this file doesn't exist either as zip or csv 20220711180000
# this file doesn't exist either as zip or csv 20220711181500
# this file doesn't exist either as zip or csv 20220711183000
# this file doesn't exist either as zip or csv 20220711184500
# this file doesn't exist either as zip or csv 20220711190000
# this file doesn't exist either as zip or csv 20220711191500
# this file doesn't exist either as zip or csv 20220711193000
# this file doesn't exist either as zip or csv 20220711194500
# this file doesn't exist either as zip or csv 20220711200000
# this file doesn't exist either as zip or csv 20220711201500
# this file doesn't exist either as zip or csv 20220711203000
# this file doesn't exist either as zip or csv 20220711204500
# this file doesn't exist either as zip or csv 20220711210000
# this file doesn't exist either as zip or csv 20220711211500
# this file doesn't exist either as zip or csv 20220711213000
# this file doesn't exist either as zip or csv 20220711214500
# this file doesn't exist either as zip or csv 20220711220000
# this file doesn't exist either as zip or csv 20220711221500
# this file doesn't exist either as zip or csv 20220711223000
# this file doesn't exist either as zip or csv 20220711224500
# this file doesn't exist either as zip or csv 20220711230000
# this file doesn't exist either as zip or csv 20220711231500
# this file doesn't exist either as zip or csv 20220711233000
# this file doesn't exist either as zip or csv 20220711234500
# this file doesn't exist either as zip or csv 20220712000000
# this file doesn't exist either as zip or csv 20220712001500
# this file doesn't exist either as zip or csv 20220712003000
# this file doesn't exist either as zip or csv 20220712004500
# this file doesn't exist either as zip or csv 20220712010000
# this file doesn't exist either as zip or csv 20220712011500
# this file doesn't exist either as zip or csv 20220712013000
# this file doesn't exist either as zip or csv 20220712014500
# this file doesn't exist either as zip or csv 20220712020000
# this file doesn't exist either as zip or csv 20220712021500
# this file doesn't exist either as zip or csv 20220712023000
# this file doesn't exist either as zip or csv 20220712024500
# this file doesn't exist either as zip or csv 20220712030000
# this file doesn't exist either as zip or csv 20220712031500
# this file doesn't exist either as zip or csv 20220712033000
# this file doesn't exist either as zip or csv 20220712034500
# this file doesn't exist either as zip or csv 20220712040000
# this file doesn't exist either as zip or csv 20220712041500
# this file doesn't exist either as zip or csv 20220712043000
# this file doesn't exist either as zip or csv 20220712044500
# this file doesn't exist either as zip or csv 20220712050000
# this file doesn't exist either as zip or csv 20220712051500
# this file doesn't exist either as zip or csv 20220712053000
# this file doesn't exist either as zip or csv 20220712054500
# this file doesn't exist either as zip or csv 20220712060000
# this file doesn't exist either as zip or csv 20220712061500
# this file doesn't exist either as zip or csv 20220712063000
# this file doesn't exist either as zip or csv 20220712064500
# this file doesn't exist either as zip or csv 20220712070000
# this file doesn't exist either as zip or csv 20220712071500
# this file doesn't exist either as zip or csv 20220712073000
# this file doesn't exist either as zip or csv 20220712074500
# this file doesn't exist either as zip or csv 20220712080000
# this file doesn't exist either as zip or csv 20220712081500
# this file doesn't exist either as zip or csv 20220712083000
# this file doesn't exist either as zip or csv 20220712084500
# this file doesn't exist either as zip or csv 20220712090000
# this file doesn't exist either as zip or csv 20220712091500
# this file doesn't exist either as zip or csv 20220712093000
# this file doesn't exist either as zip or csv 20220712094500
# this file doesn't exist either as zip or csv 20220712100000
# this file doesn't exist either as zip or csv 20220712101500
# this file doesn't exist either as zip or csv 20220712103000
# this file doesn't exist either as zip or csv 20220712104500
# this file doesn't exist either as zip or csv 20220712110000
# this file doesn't exist either as zip or csv 20220712111500
# this file doesn't exist either as zip or csv 20220712113000
# this file doesn't exist either as zip or csv 20220712114500
# this file doesn't exist either as zip or csv 20220712120000
# this file doesn't exist either as zip or csv 20220712121500
# this file doesn't exist either as zip or csv 20220712123000
# this file doesn't exist either as zip or csv 20220712124500
# this file doesn't exist either as zip or csv 20220712130000
# this file doesn't exist either as zip or csv 20220712131500
# this file doesn't exist either as zip or csv 20220712133000
# this file doesn't exist either as zip or csv 20220712134500
# this file doesn't exist either as zip or csv 20220712140000
# this file doesn't exist either as zip or csv 20220712141500
# this file doesn't exist either as zip or csv 20220712143000
# this file doesn't exist either as zip or csv 20220712144500
# this file doesn't exist either as zip or csv 20220712150000
# this file doesn't exist either as zip or csv 20220712151500
# this file doesn't exist either as zip or csv 20220712153000
# this file doesn't exist either as zip or csv 20220712154500
# this file doesn't exist either as zip or csv 20220712160000
# this file doesn't exist either as zip or csv 20220712161500
# this file doesn't exist either as zip or csv 20220712163000
# this file doesn't exist either as zip or csv 20220712164500
# this file doesn't exist either as zip or csv 20220712170000
# this file doesn't exist either as zip or csv 20220712171500
# this file doesn't exist either as zip or csv 20220712173000
# this file doesn't exist either as zip or csv 20220712174500
# this file doesn't exist either as zip or csv 20220712180000
# this file doesn't exist either as zip or csv 20220712181500
# this file doesn't exist either as zip or csv 20220712183000
# this file doesn't exist either as zip or csv 20220712184500
# this file doesn't exist either as zip or csv 20220712190000
# this file doesn't exist either as zip or csv 20220712191500
# this file doesn't exist either as zip or csv 20220712193000
# this file doesn't exist either as zip or csv 20220712194500
# this file doesn't exist either as zip or csv 20220712200000
# this file doesn't exist either as zip or csv 20220712201500
# this file doesn't exist either as zip or csv 20220712203000
# this file doesn't exist either as zip or csv 20220712204500
# this file doesn't exist either as zip or csv 20220712210000
# this file doesn't exist either as zip or csv 20220712211500
# this file doesn't exist either as zip or csv 20220712213000
# this file doesn't exist either as zip or csv 20220712214500
# this file doesn't exist either as zip or csv 20220712220000
# this file doesn't exist either as zip or csv 20220712221500
# this file doesn't exist either as zip or csv 20220712223000
# this file doesn't exist either as zip or csv 20220712224500
# this file doesn't exist either as zip or csv 20220712230000
# this file doesn't exist either as zip or csv 20220712231500
# this file doesn't exist either as zip or csv 20220712233000
# this file doesn't exist either as zip or csv 20220712234500
# this file doesn't exist either as zip or csv 20220713000000
# this file doesn't exist either as zip or csv 20220713001500
# this file doesn't exist either as zip or csv 20220713003000
# this file doesn't exist either as zip or csv 20220713004500
# this file doesn't exist either as zip or csv 20220713010000
# this file doesn't exist either as zip or csv 20220713011500
# this file doesn't exist either as zip or csv 20220713013000
# this file doesn't exist either as zip or csv 20220713014500
# this file doesn't exist either as zip or csv 20220713020000
# this file doesn't exist either as zip or csv 20220713021500
# this file doesn't exist either as zip or csv 20220713023000
# this file doesn't exist either as zip or csv 20220713024500
# this file doesn't exist either as zip or csv 20220713030000
# this file doesn't exist either as zip or csv 20220713031500
# this file doesn't exist either as zip or csv 20220713033000
# this file doesn't exist either as zip or csv 20220713034500
# this file doesn't exist either as zip or csv 20220713040000
# this file doesn't exist either as zip or csv 20220713041500
# this file doesn't exist either as zip or csv 20220713043000
# this file doesn't exist either as zip or csv 20220713044500
# this file doesn't exist either as zip or csv 20220713050000
# this file doesn't exist either as zip or csv 20220713051500
# this file doesn't exist either as zip or csv 20220713053000
# this file doesn't exist either as zip or csv 20220713054500
# this file doesn't exist either as zip or csv 20220713060000
# this file doesn't exist either as zip or csv 20220713061500
# this file doesn't exist either as zip or csv 20220713063000
# this file doesn't exist either as zip or csv 20220713064500
# this file doesn't exist either as zip or csv 20220713070000
# this file doesn't exist either as zip or csv 20220713071500
# this file doesn't exist either as zip or csv 20220713073000
# this file doesn't exist either as zip or csv 20220713074500
# this file doesn't exist either as zip or csv 20220713080000
# this file doesn't exist either as zip or csv 20220713081500
# this file doesn't exist either as zip or csv 20220713083000
# this file doesn't exist either as zip or csv 20220713084500
# this file doesn't exist either as zip or csv 20220713090000
# this file doesn't exist either as zip or csv 20220713091500
# this file doesn't exist either as zip or csv 20220713093000
# this file doesn't exist either as zip or csv 20220713094500
# this file doesn't exist either as zip or csv 20220713100000
# this file doesn't exist either as zip or csv 20220713101500
# this file doesn't exist either as zip or csv 20220713103000
# this file doesn't exist either as zip or csv 20220713104500
# this file doesn't exist either as zip or csv 20220713110000
# this file doesn't exist either as zip or csv 20220713111500
# this file doesn't exist either as zip or csv 20220713113000
# this file doesn't exist either as zip or csv 20220713114500
# this file doesn't exist either as zip or csv 20220713120000
# this file doesn't exist either as zip or csv 20220713121500
# this file doesn't exist either as zip or csv 20220713123000
# this file doesn't exist either as zip or csv 20220713124500
# this file doesn't exist either as zip or csv 20220713130000
# this file doesn't exist either as zip or csv 20220713131500
# this file doesn't exist either as zip or csv 20220713133000
# this file doesn't exist either as zip or csv 20220713134500
# this file doesn't exist either as zip or csv 20220713140000
# this file doesn't exist either as zip or csv 20220713141500
# this file doesn't exist either as zip or csv 20220713143000
# this file doesn't exist either as zip or csv 20220713144500
# this file doesn't exist either as zip or csv 20220713150000
# this file doesn't exist either as zip or csv 20220713151500
# this file doesn't exist either as zip or csv 20220713153000
# this file doesn't exist either as zip or csv 20220713154500
# this file doesn't exist either as zip or csv 20220713160000
# this file doesn't exist either as zip or csv 20220713161500
# this file doesn't exist either as zip or csv 20220713163000
# this file doesn't exist either as zip or csv 20220713164500
# this file doesn't exist either as zip or csv 20220713170000
# this file doesn't exist either as zip or csv 20220713171500
# this file doesn't exist either as zip or csv 20220713173000
# this file doesn't exist either as zip or csv 20220713174500
# this file doesn't exist either as zip or csv 20220713180000
# this file doesn't exist either as zip or csv 20220713181500
# this file doesn't exist either as zip or csv 20220713183000
# this file doesn't exist either as zip or csv 20220713184500
# this file doesn't exist either as zip or csv 20220713190000
# this file doesn't exist either as zip or csv 20220713191500
# this file doesn't exist either as zip or csv 20220713193000
# this file doesn't exist either as zip or csv 20220713194500
# this file doesn't exist either as zip or csv 20220713200000
# this file doesn't exist either as zip or csv 20220713201500
# this file doesn't exist either as zip or csv 20220713203000
# this file doesn't exist either as zip or csv 20220713204500
# this file doesn't exist either as zip or csv 20220713210000
# this file doesn't exist either as zip or csv 20220713211500
# this file doesn't exist either as zip or csv 20220713213000
# this file doesn't exist either as zip or csv 20220713214500
# this file doesn't exist either as zip or csv 20220713220000
# this file doesn't exist either as zip or csv 20220713221500
# this file doesn't exist either as zip or csv 20220713223000
# this file doesn't exist either as zip or csv 20220713224500
# this file doesn't exist either as zip or csv 20220713230000
# this file doesn't exist either as zip or csv 20220713231500
# this file doesn't exist either as zip or csv 20220713233000
# this file doesn't exist either as zip or csv 20220713234500
# this file doesn't exist either as zip or csv 20220714000000
# this file doesn't exist either as zip or csv 20220714001500
# this file doesn't exist either as zip or csv 20220714003000
# this file doesn't exist either as zip or csv 20220714004500
# this file doesn't exist either as zip or csv 20220714010000
# this file doesn't exist either as zip or csv 20220714011500
# this file doesn't exist either as zip or csv 20220714013000
# this file doesn't exist either as zip or csv 20220714014500
# this file doesn't exist either as zip or csv 20220714020000
# this file doesn't exist either as zip or csv 20220714021500
# this file doesn't exist either as zip or csv 20220714023000
# this file doesn't exist either as zip or csv 20220714024500
# this file doesn't exist either as zip or csv 20220714030000
# this file doesn't exist either as zip or csv 20220714031500
# this file doesn't exist either as zip or csv 20220714033000
# this file doesn't exist either as zip or csv 20220714034500
# this file doesn't exist either as zip or csv 20220714040000
# this file doesn't exist either as zip or csv 20220714041500
# this file doesn't exist either as zip or csv 20220714043000
# this file doesn't exist either as zip or csv 20220714044500
# this file doesn't exist either as zip or csv 20220714050000
# this file doesn't exist either as zip or csv 20220714051500
# this file doesn't exist either as zip or csv 20220714053000
# this file doesn't exist either as zip or csv 20220714054500
# this file doesn't exist either as zip or csv 20220714060000
# this file doesn't exist either as zip or csv 20220714061500
# this file doesn't exist either as zip or csv 20220714063000
# this file doesn't exist either as zip or csv 20220714064500
# this file doesn't exist either as zip or csv 20220714070000
# this file doesn't exist either as zip or csv 20220714071500
# this file doesn't exist either as zip or csv 20220714073000
# this file doesn't exist either as zip or csv 20220714074500
# this file doesn't exist either as zip or csv 20220714080000
# this file doesn't exist either as zip or csv 20220714081500
# this file doesn't exist either as zip or csv 20220714083000
# this file doesn't exist either as zip or csv 20220714084500
# this file doesn't exist either as zip or csv 20220714090000
# this file doesn't exist either as zip or csv 20220714091500
# this file doesn't exist either as zip or csv 20220714093000
# this file doesn't exist either as zip or csv 20220714094500
# this file doesn't exist either as zip or csv 20220714100000
# this file doesn't exist either as zip or csv 20220714101500
# this file doesn't exist either as zip or csv 20220714103000
# this file doesn't exist either as zip or csv 20220714104500
# this file doesn't exist either as zip or csv 20220714110000
# this file doesn't exist either as zip or csv 20220714111500
# this file doesn't exist either as zip or csv 20220714113000
# this file doesn't exist either as zip or csv 20220714114500
# this file doesn't exist either as zip or csv 20220714120000
# this file doesn't exist either as zip or csv 20220714121500
# this file doesn't exist either as zip or csv 20220714123000
# this file doesn't exist either as zip or csv 20220714124500
# this file doesn't exist either as zip or csv 20220714130000
# this file doesn't exist either as zip or csv 20220714131500
# this file doesn't exist either as zip or csv 20220714133000
# this file doesn't exist either as zip or csv 20220714134500
# this file doesn't exist either as zip or csv 20220714140000
# this file doesn't exist either as zip or csv 20220714141500
# this file doesn't exist either as zip or csv 20220714143000
# this file doesn't exist either as zip or csv 20220714144500
# this file doesn't exist either as zip or csv 20220714150000
# this file doesn't exist either as zip or csv 20220714151500
# this file doesn't exist either as zip or csv 20220714153000
# this file doesn't exist either as zip or csv 20220714154500
# this file doesn't exist either as zip or csv 20220714160000
# this file doesn't exist either as zip or csv 20220714161500
# this file doesn't exist either as zip or csv 20220714163000
# this file doesn't exist either as zip or csv 20220714164500
# this file doesn't exist either as zip or csv 20220714170000
# this file doesn't exist either as zip or csv 20220714171500
# this file doesn't exist either as zip or csv 20220714173000
# this file doesn't exist either as zip or csv 20220714174500
# this file doesn't exist either as zip or csv 20220714180000
# this file doesn't exist either as zip or csv 20220714181500
# this file doesn't exist either as zip or csv 20220714183000
# this file doesn't exist either as zip or csv 20220714184500
# this file doesn't exist either as zip or csv 20220714190000
# this file doesn't exist either as zip or csv 20220714191500
# this file doesn't exist either as zip or csv 20220714193000
# this file doesn't exist either as zip or csv 20220714194500
# this file doesn't exist either as zip or csv 20220714200000
# ...
# this file doesn't exist either as zip or csv 20221028094500
# this file doesn't exist either as zip or csv 20221028100000
# this file doesn't exist either as zip or csv 20221028101500
# this file doesn't exist either as zip or csv 20221028103000
# this file doesn't exist either as zip or csv 20221028104500
# this file doesn't exist either as zip or csv 20221028110000
# this file doesn't exist either as zip or csv 20221028111500
# this file doesn't exist either as zip or csv 20221028113000
# this file doesn't exist either as zip or csv 20221028114500
# this file doesn't exist either as zip or csv 20221028120000
# this file doesn't exist either as zip or csv 20221028121500
# this file doesn't exist either as zip or csv 20221028123000
# this file doesn't exist either as zip or csv 20221028124500
# this file doesn't exist either as zip or csv 20221028130000
# this file doesn't exist either as zip or csv 20221028131500
# this file doesn't exist either as zip or csv 20221028133000
# this file doesn't exist either as zip or csv 20221028134500
# this file doesn't exist either as zip or csv 20221028140000
# this file doesn't exist either as zip or csv 20221028141500
# this file doesn't exist either as zip or csv 20221028143000
# this file doesn't exist either as zip or csv 20221028144500
# this file doesn't exist either as zip or csv 20221028150000
# this file doesn't exist either as zip or csv 20221028151500
# this file doesn't exist either as zip or csv 20221028153000
# this file doesn't exist either as zip or csv 20221028154500
# this file doesn't exist either as zip or csv 20221028160000
# this file doesn't exist either as zip or csv 20221028161500
# this file doesn't exist either as zip or csv 20221028163000
# this file doesn't exist either as zip or csv 20221028164500
# this file doesn't exist either as zip or csv 20221028170000
# this file doesn't exist either as zip or csv 20221028171500
# this file doesn't exist either as zip or csv 20221028173000
# this file doesn't exist either as zip or csv 20221028174500
# this file doesn't exist either as zip or csv 20221028180000
# this file doesn't exist either as zip or csv 20221028181500
# this file doesn't exist either as zip or csv 20221028183000
# this file doesn't exist either as zip or csv 20221028184500
# this file doesn't exist either as zip or csv 20221028190000
# this file doesn't exist either as zip or csv 20221028191500
# this file doesn't exist either as zip or csv 20221028193000
# this file doesn't exist either as zip or csv 20221028194500
# this file doesn't exist either as zip or csv 20221028200000
# this file doesn't exist either as zip or csv 20221028201500
# this file doesn't exist either as zip or csv 20221028203000
# this file doesn't exist either as zip or csv 20221028204500
# this file doesn't exist either as zip or csv 20221028210000
# this file doesn't exist either as zip or csv 20221028211500
# this file doesn't exist either as zip or csv 20221028213000
# this file doesn't exist either as zip or csv 20221028214500
# this file doesn't exist either as zip or csv 20221028220000
# this file doesn't exist either as zip or csv 20221028221500
# this file doesn't exist either as zip or csv 20221028223000
# this file doesn't exist either as zip or csv 20221028224500
# this file doesn't exist either as zip or csv 20221028230000
# this file doesn't exist either as zip or csv 20221028231500
# this file doesn't exist either as zip or csv 20221028233000
# this file doesn't exist either as zip or csv 20221028234500
# this file doesn't exist either as zip or csv 20221029000000
# this file doesn't exist either as zip or csv 20221029001500
# this file doesn't exist either as zip or csv 20221029003000
# this file doesn't exist either as zip or csv 20221029004500
# this file doesn't exist either as zip or csv 20221029010000
# this file doesn't exist either as zip or csv 20221029011500
# this file doesn't exist either as zip or csv 20221029013000
# this file doesn't exist either as zip or csv 20221029014500
# this file doesn't exist either as zip or csv 20221029020000
# this file doesn't exist either as zip or csv 20221029021500
# this file doesn't exist either as zip or csv 20221029023000
# this file doesn't exist either as zip or csv 20221029024500
# this file doesn't exist either as zip or csv 20221029030000
# this file doesn't exist either as zip or csv 20221029031500
# this file doesn't exist either as zip or csv 20221029033000
# this file doesn't exist either as zip or csv 20221029034500
# this file doesn't exist either as zip or csv 20221029040000
# this file doesn't exist either as zip or csv 20221029041500
# this file doesn't exist either as zip or csv 20221029043000
# this file doesn't exist either as zip or csv 20221029044500
# this file doesn't exist either as zip or csv 20221029050000
# this file doesn't exist either as zip or csv 20221029051500
# this file doesn't exist either as zip or csv 20221029053000
# this file doesn't exist either as zip or csv 20221029054500
# this file doesn't exist either as zip or csv 20221029060000
# this file doesn't exist either as zip or csv 20221029061500
# this file doesn't exist either as zip or csv 20221029063000
# this file doesn't exist either as zip or csv 20221029064500
# this file doesn't exist either as zip or csv 20221029070000
# this file doesn't exist either as zip or csv 20221029071500
# this file doesn't exist either as zip or csv 20221029073000
# this file doesn't exist either as zip or csv 20221029074500
# this file doesn't exist either as zip or csv 20221029080000
# this file doesn't exist either as zip or csv 20221029081500
# this file doesn't exist either as zip or csv 20221029083000
# this file doesn't exist either as zip or csv 20221029084500
# this file doesn't exist either as zip or csv 20221029090000
# this file doesn't exist either as zip or csv 20221029091500
# this file doesn't exist either as zip or csv 20221029093000
# this file doesn't exist either as zip or csv 20221029094500
# this file doesn't exist either as zip or csv 20221029100000
# this file doesn't exist either as zip or csv 20221029101500
# this file doesn't exist either as zip or csv 20221029103000
# this file doesn't exist either as zip or csv 20221029104500
# this file doesn't exist either as zip or csv 20221029110000
# this file doesn't exist either as zip or csv 20221029111500
# this file doesn't exist either as zip or csv 20221029113000
# this file doesn't exist either as zip or csv 20221029114500
# this file doesn't exist either as zip or csv 20221029120000
# this file doesn't exist either as zip or csv 20221029121500
# this file doesn't exist either as zip or csv 20221029123000
# this file doesn't exist either as zip or csv 20221029124500
# this file doesn't exist either as zip or csv 20221029130000
# this file doesn't exist either as zip or csv 20221029131500
# this file doesn't exist either as zip or csv 20221029133000
# this file doesn't exist either as zip or csv 20221029134500
# this file doesn't exist either as zip or csv 20221029140000
# this file doesn't exist either as zip or csv 20221029141500
# this file doesn't exist either as zip or csv 20221029143000
# this file doesn't exist either as zip or csv 20221029144500
# this file doesn't exist either as zip or csv 20221029150000
# this file doesn't exist either as zip or csv 20221029151500
# this file doesn't exist either as zip or csv 20221029153000
# this file doesn't exist either as zip or csv 20221029154500
# this file doesn't exist either as zip or csv 20221029160000
# this file doesn't exist either as zip or csv 20221029161500
# this file doesn't exist either as zip or csv 20221029163000
# this file doesn't exist either as zip or csv 20221029164500
# this file doesn't exist either as zip or csv 20221029170000
# this file doesn't exist either as zip or csv 20221029171500
# this file doesn't exist either as zip or csv 20221029173000
# this file doesn't exist either as zip or csv 20221029174500
# this file doesn't exist either as zip or csv 20221029180000
# this file doesn't exist either as zip or csv 20221029181500
# this file doesn't exist either as zip or csv 20221029183000
# this file doesn't exist either as zip or csv 20221029184500
# this file doesn't exist either as zip or csv 20221029190000
# this file doesn't exist either as zip or csv 20221029191500
# this file doesn't exist either as zip or csv 20221029193000
# this file doesn't exist either as zip or csv 20221029194500
# this file doesn't exist either as zip or csv 20221029200000
# this file doesn't exist either as zip or csv 20221029201500
# this file doesn't exist either as zip or csv 20221029203000
# this file doesn't exist either as zip or csv 20221029204500
# this file doesn't exist either as zip or csv 20221029210000
# this file doesn't exist either as zip or csv 20221029211500
# this file doesn't exist either as zip or csv 20221029213000
# this file doesn't exist either as zip or csv 20221029214500
# this file doesn't exist either as zip or csv 20221029220000
# this file doesn't exist either as zip or csv 20221029221500
# this file doesn't exist either as zip or csv 20221029223000
# this file doesn't exist either as zip or csv 20221029224500
# this file doesn't exist either as zip or csv 20221029230000
# this file doesn't exist either as zip or csv 20221029231500
# this file doesn't exist either as zip or csv 20221029233000
# this file doesn't exist either as zip or csv 20221029234500
# this file doesn't exist either as zip or csv 20221030000000
# this file doesn't exist either as zip or csv 20221030001500
# this file doesn't exist either as zip or csv 20221030003000
# this file doesn't exist either as zip or csv 20221030004500
# this file doesn't exist either as zip or csv 20221030010000
# this file doesn't exist either as zip or csv 20221105041500
# this file doesn't exist either as zip or csv 20221106223000
# this file doesn't exist either as zip or csv 20221110013000
# this file doesn't exist either as zip or csv 20221110220000
# this file doesn't exist either as zip or csv 20221110221500
# this file doesn't exist either as zip or csv 20221110223000
# this file doesn't exist either as zip or csv 20221110224500
# this file doesn't exist either as zip or csv 20221110230000
# this file doesn't exist either as zip or csv 20221110231500
# this file doesn't exist either as zip or csv 20221110233000
# this file doesn't exist either as zip or csv 20221110234500
# this file doesn't exist either as zip or csv 20221111000000
# this file doesn't exist either as zip or csv 20221111001500
# this file doesn't exist either as zip or csv 20221111003000
# this file doesn't exist either as zip or csv 20221111004500
# this file doesn't exist either as zip or csv 20221111010000
# this file doesn't exist either as zip or csv 20221111011500
# this file doesn't exist either as zip or csv 20221111013000
# this file doesn't exist either as zip or csv 20221111014500
# this file doesn't exist either as zip or csv 20221111020000
# this file doesn't exist either as zip or csv 20221111021500
# this file doesn't exist either as zip or csv 20221111023000
# this file doesn't exist either as zip or csv 20221111024500
# this file doesn't exist either as zip or csv 20221111030000
# this file doesn't exist either as zip or csv 20221111031500
# this file doesn't exist either as zip or csv 20221111033000
# this file doesn't exist either as zip or csv 20221111034500
# this file doesn't exist either as zip or csv 20221111040000
# this file doesn't exist either as zip or csv 20221111041500
# this file doesn't exist either as zip or csv 20221111043000
# this file doesn't exist either as zip or csv 20221111044500
# this file doesn't exist either as zip or csv 20221111050000
# this file doesn't exist either as zip or csv 20221111051500
# this file doesn't exist either as zip or csv 20221111053000
# this file doesn't exist either as zip or csv 20221111054500
# this file doesn't exist either as zip or csv 20221111060000
# this file doesn't exist either as zip or csv 20221111061500
# this file doesn't exist either as zip or csv 20221111063000
# this file doesn't exist either as zip or csv 20221111064500
# this file doesn't exist either as zip or csv 20221111070000
# this file doesn't exist either as zip or csv 20221111071500
# this file doesn't exist either as zip or csv 20221111073000
# this file doesn't exist either as zip or csv 20221111074500
# this file doesn't exist either as zip or csv 20221111080000
# this file doesn't exist either as zip or csv 20221111081500
# this file doesn't exist either as zip or csv 20221111083000
# this file doesn't exist either as zip or csv 20221111084500
# this file doesn't exist either as zip or csv 20221111090000
# this file doesn't exist either as zip or csv 20221111091500
# this file doesn't exist either as zip or csv 20221111093000
# this file doesn't exist either as zip or csv 20221111094500
# this file doesn't exist either as zip or csv 20221111100000
# this file doesn't exist either as zip or csv 20221111101500
# this file doesn't exist either as zip or csv 20221111103000
# this file doesn't exist either as zip or csv 20221111104500
# this file doesn't exist either as zip or csv 20221111110000
# this file doesn't exist either as zip or csv 20221111111500
# this file doesn't exist either as zip or csv 20221111113000
# this file doesn't exist either as zip or csv 20221111114500
# this file doesn't exist either as zip or csv 20221111120000
# this file doesn't exist either as zip or csv 20221111121500
# this file doesn't exist either as zip or csv 20221111123000
# this file doesn't exist either as zip or csv 20221111124500
# this file doesn't exist either as zip or csv 20221111130000
# this file doesn't exist either as zip or csv 20221111131500
# this file doesn't exist either as zip or csv 20221111133000
# this file doesn't exist either as zip or csv 20221111134500
# this file doesn't exist either as zip or csv 20221111140000
# this file doesn't exist either as zip or csv 20221111141500
# this file doesn't exist either as zip or csv 20221111143000
# this file doesn't exist either as zip or csv 20221111144500
# this file doesn't exist either as zip or csv 20221111150000
# this file doesn't exist either as zip or csv 20221111151500
# this file doesn't exist either as zip or csv 20221111153000
# this file doesn't exist either as zip or csv 20221111154500
# this file doesn't exist either as zip or csv 20221111160000
# this file doesn't exist either as zip or csv 20221111161500
# this file doesn't exist either as zip or csv 20221111163000
# this file doesn't exist either as zip or csv 20221111164500
# this file doesn't exist either as zip or csv 20221111170000
# this file doesn't exist either as zip or csv 20221111171500
# this file doesn't exist either as zip or csv 20221111173000
# this file doesn't exist either as zip or csv 20221111174500
# this file doesn't exist either as zip or csv 20221111180000
# this file doesn't exist either as zip or csv 20221111181500
# this file doesn't exist either as zip or csv 20221111183000
# this file doesn't exist either as zip or csv 20221112151500
# this file doesn't exist either as zip or csv 20221117130000
# this file doesn't exist either as zip or csv 20221120221500
# this file doesn't exist either as zip or csv 20221123050000
# this file doesn't exist either as zip or csv 20221125103000
# this file doesn't exist either as zip or csv 20221126173000
# this file doesn't exist either as zip or csv 20221128071500
# this file doesn't exist either as zip or csv 20221207220000
# this file doesn't exist either as zip or csv 20221212013000
# this file doesn't exist either as zip or csv 20221215010000
# this file doesn't exist either as zip or csv 20221215164500
# this file doesn't exist either as zip or csv 20221215213000
# this file doesn't exist either as zip or csv 20221219171500
# this file doesn't exist either as zip or csv 20221221083000
# this file doesn't exist either as zip or csv 20221221223000
# this file doesn't exist either as zip or csv 20221222074500
# this file doesn't exist either as zip or csv 20221222173000
# this file doesn't exist either as zip or csv 20221222190000
# this file doesn't exist either as zip or csv 20221222191500
# this file doesn't exist either as zip or csv 20221222193000
# this file doesn't exist either as zip or csv 20221222231500
# this file doesn't exist either as zip or csv 20221226074500
# 1803

# %%
# testing
os.path.exists("20221226074500.csv")
# Out:
# False

# %%
# testing
samples[samples["Date"] == 20221226074500]
# Out:
#                  Date                                                URL  \
# 34490  20221226074500  http://data.gdeltproject.org/gdeltv2/202212260...
#
#       Date_formatted
# 34490     2022-12-26
